# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Saeed Malekifar__
#
# I am currently a student.

# %% [markdown]
# _I am interested in data science because finding patterns in data is amazing!_

# %% [markdown]
# ### The pice of code below is going to print a string.

# %%
string = "This is the week 3 final assignment."
print(string)
# Out:
# This is the week 3 final assignment.

# %% [markdown]
# 1. one
# 2. two
# 3. three
#
# * first
# * second
# * third
# ***
# ***
#
# |name|age|
# |----|---|
# |saeed|29|
